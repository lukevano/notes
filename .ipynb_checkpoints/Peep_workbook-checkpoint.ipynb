# %%
# Install Statsmodels
# Adapted from https://www.statsmodels.org/stable/examples/notebooks/generated/mixed_lm_example.html
#!pip install -q statsmodels

# Load packages
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Load dataset
data = sm.datasets.get_rdataset('dietox', 'geepack').data

# Run LMER
md = smf.mixedlm("Weight ~ Time", data, groups=data["Pig"], re_formula="~Time")
mdf = md.fit(method=["lbfgs"])
print(mdf.summary())
# Out:
#            Mixed Linear Model Regression Results
# ...
# Model:             MixedLM  Dependent Variable:  Weight
# No. Observations:  861      Method:              REML
# No. Groups:        72       Scale:               6.0372
# Min. group size:   11       Log-Likelihood:      -2217.0475
# Max. group size:   12       Converged:           Yes
# Mean group size:   12.0
# -----------------------------------------------------------
#                  Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------
# Intercept        15.739    0.550 28.603 0.000 14.660 16.817
# Time              6.939    0.080 86.925 0.000  6.783  7.095
# Group Var        19.503    1.561
# Group x Time Cov  0.294    0.153
# Time Var          0.416    0.033
# ...

# %%
data = pd.read_csv("/Users/DrV/PyProj/peep/Intake3.csv")

# %%
data_c = data.copy()

# %%
data_c.shape
# Out:
# (80, 135)

# %%
data_c
# Out:
#     GROUP  Start Date                 Name   Age  Gender  Medical Programme  \
# 0       0  2015-10-09      Aarushi Agrawal  17.0       0                  0
# 1       1  2015-10-13        Aayenah Yunus  18.0       0                  0
# 2       1  2015-10-11    Abinaya Sivapalan  18.0       0                  0
# 3       1  2015-10-10  Abrar Jaheen Rushad  18.0       1                  0
# 4       0  2015-10-07          Afshan Khan  21.0       0                  2
# ..    ...         ...                  ...   ...     ...                ...
# 75      1  2015-10-09        Stewart Smith  23.0       1                  0
# 76      0  2015-10-09     Tara Etherington  23.0       0                  0
# 77      1  2015-10-09       Tasnima Khanom  19.0       0                  2
# 78      1  2015-10-08    Viktorie Schutova  20.0       0                  0
# 79      0  2015-10-09     Yanina Pecherska  22.0       0                  0
#
# ...

# %%
data_cut = data_c[['GROUP', 'Age', 'Gender', 'ATP0', 'ATP1', 'ATP2', 'Speciality0', 'Speciality1', 'Speciality2']]

# %%
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer(max_iter=30)
imp.fit(data_cut)
# Out:
# IterativeImputer(max_iter=30)

# %%
imputed_data = imp.transform(data_cut)

# %%
imputed_data.shape
# Out:
# (80, 9)

# %%
pd.DataFrame(data= imputed_data, columns= data_cut.columns)
# Out:
#     GROUP   Age  Gender   ATP0        ATP1        ATP2  Speciality0  \
# 0     0.0  17.0     0.0  134.0  132.000000  135.000000          1.0
# 1     1.0  18.0     0.0  121.0  112.000000  115.195387          1.0
# 2     1.0  18.0     0.0  131.0  124.792815  123.000000          1.0
# 3     1.0  18.0     1.0  121.0  109.000000  113.590078          1.0
# 4     0.0  21.0     0.0  123.0  118.000000  115.000000          1.0
# ..    ...   ...     ...    ...         ...         ...          ...
# 75    1.0  23.0     1.0  127.0  125.000000  129.000000          1.0
# 76    0.0  23.0     0.0  134.0  130.000000  137.000000          1.0
# 77    1.0  19.0     0.0  115.0  118.374156  116.518269          1.0
# 78    1.0  20.0     0.0  118.0  121.000000  113.000000          1.0
# 79    0.0  22.0     0.0  134.0  142.000000  145.000000          1.0
#
#     Speciality1  Speciality2
# 0      1.000000     0.000000
# 1      1.000000     0.600894
# 2      0.718070     1.000000
# 3      1.000000     0.596446
# ...
